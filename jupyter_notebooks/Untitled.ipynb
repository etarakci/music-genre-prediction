# %%
import pandas as pd

# %%
data = pd.read_csv("data/spotify_df.csv")

# %%
data.head()
# Out:
#         artist_name          track_name                track_id  \
# 0        jason mraz           i'm yours  1EzrEOXmMH3G43AXT1y7pA
# 1  chord overstreet             hold on  5vjLSffimiIP26QG5WcN2K
# 2    matt nathanson  come on get higher  38YgZVHPWOWsKrsCXz6JyP
# 3    sara bareilles           love song  4E6cwWJWZw2zWf7VFbH7wf
# 4        jason mraz     i won't give up  53QF56cjZA9RTuuMZDrSA6
#
#                                          artist_href  \
# 0  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 1  https://open.spotify.com/artist/5D3muNJhYYunbR...
# 2  https://open.spotify.com/artist/4NGiEU3Pkd8ASR...
# 3  https://open.spotify.com/artist/2Sqr0DXoaYABbj...
# 4  https://open.spotify.com/artist/4phGZZrJZRo4El...
#
#                                           track_href genre_name  danceability  \
# 0  https://open.spotify.com/track/1EzrEOXmMH3G43A...   acoustic         0.686
# 1  https://open.spotify.com/track/5vjLSffimiIP26Q...   acoustic         0.618
# ...

# %%
data['genre_name'].nunique()
# Out:
# 111

# %%
data2 = pd.read_csv("data/genre_lyrics_sound_data.csv")

# %%
data2.head()
# Out:
#    Unnamed: 0     artist_name track_name                track_id  \
# 0           0      jason mraz  i'm yours  1EzrEOXmMH3G43AXT1y7pA
# 1           1  sara bareilles  love song  4E6cwWJWZw2zWf7VFbH7wf
# 2           2  colbie caillat     bubbly  0rFOs9paloAvEtzwDX1Kmc
# 3           3      jason mraz      lucky  0IktbUcnAGrvD03AWnz3Q8
# 4           4    edwin mccain    i'll be  5K7AMlpc4796JRWXb26nCV
#
#                                          artist_href  \
# 0  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 1  https://open.spotify.com/artist/2Sqr0DXoaYABbj...
# 2  https://open.spotify.com/artist/6aZyMrc4doVtZy...
# 3  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 4  https://open.spotify.com/artist/0L6Gwm0JDrgIQJ...
#
#                                           track_href genre_name  danceability  \
# 0  https://open.spotify.com/track/1EzrEOXmMH3G43A...   acoustic         0.686
# 1  https://open.spotify.com/track/4E6cwWJWZw2zWf7...   acoustic         0.583
# ...

# %%
data.genre_name.nunique()
# Out:
# 111
