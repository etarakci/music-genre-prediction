# %%
# pip install spotipy

# %%
# pip install spotipy --upgrade

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

cid = '3be62ceebcef44a1807e9002adf8d159'
secret = 'bde76e0d3cd54a68b6ca267237bf7e0e'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Data Exploration

# artist_name = []
# track_name = []
# popularity = []
# track_id = []
# artist_href = []
# track_href = []
# album_image = []


# for i in range(0,50,50):
#     track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
#     for i, t in enumerate(track_results['tracks']['items']):
#         artist_name.append(t['artists'][0]['name'])
#         track_name.append(t['name'])
#         track_id.append(t['id'])
#         popularity.append(t['popularity'])
#         artist_href.append(t['artists'][0]['external_urls']['spotify'])
#         track_href.append(t['external_urls']['spotify'])
#         album_image.append(t['album']['images'][0]['url'])

# %%
# Data Exploration

# pp.pprint(track_results)

# %%
# Data Exploration

# test_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'album_image' : album_image})
# test_df['album_image'][0]

# %%
# Data Exploration

# len(track_results['tracks']['items'])

# %%
# Data Exploration
# import pprint
# pp = pprint.PrettyPrinter(indent=4)

# pp.pprint(track_results['tracks']['items'])

# %%
# Data Exploration
# example on how to get the list of names of all the albums released by artist Birdy

# birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'

# results = sp.artist_albums(birdy_uri, album_type='album')

# albums = results['items']

# while results['next']:
#     results = sp.next(results)
#     albums.extend(results['items'])

# for album in albums:
#     print(album['name'])

# %%
# getting the list of genres from Spotify API

genres = []
None_counter = 0

for i in range(0,2000,50):
    results = sp.recommendation_genre_seeds()
    for i, t in enumerate(results):
        if t == None:
            None_counter = None_counter + 1
        else:
            genres.append(t)

# %%
# Data Exploration

# len(results['genres'])

# %%
# Data Exploration

# results

# %%
# Now going thorought the 126 genres and request Spotify API to return 112,000 artist name, track name and genre name
# Used for lyrics/genre merge

artist_name = []
track_name = []
genre_name = []


for genre in results['genres']:
    # print(genre)
    for i in range(0,1000,50):
        q1 = 'genre:'+str(genre)
        genre_results = sp.search(q=q1, type='track', limit=50,offset=i)
        for i, t in enumerate(genre_results['tracks']['items']):
            artist_name.append(t['artists'][0]['name'])
            track_name.append(t['name'])
            genre_name.append([genre])

# %%
# Genre Dataframe

import pandas as pd

genre_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'genre_name' : genre_name})
print(genre_dataframe.shape)
# Out:
# (112000, 3)

# %%
# Data Exploration

# genre_dataframe
len(genre_dataframe)
# Out:
# 112000

# %%
# Data Cleanup

genre_dataframe['track_name'] = genre_dataframe['track_name'].apply(lambda row: row.lower())
genre_dataframe['artist_name'] = genre_dataframe['artist_name'].apply(lambda row: row.lower())
genre_dataframe['genre_name'] = genre_dataframe['genre_name'].str[0]

# %%
# convert to csv

import pandas as pd
genre_dataframe.to_csv ('genre_dataframe.csv', index = False, header=True)

# %%
# Data Exploration
# rap_results['tracks']['items'][0]

# %%
# Data Exploration
# artist_name

# %%
# Data Exploration

# artist_name = []
# track_name = []


# for i in range(0,100,50):
#     pop_results = sp.search(q='genre:pop', type='track', limit=50,offset=i)
#     for i, t in enumerate(track_results['tracks']['items']):
#         artist_name.append(t['artists'][0]['name'])
#         track_name.append(t['name'])

# %%
# Data Exploration

# import pprint
# pp = pprint.PrettyPrinter(indent=1)
# pp.pprint(pop_results)

# %%
# Data Exploration

# artist_name = []
# track_name = []
# popularity = []
# track_id = []
# artist_href = []
# track_href = []
# album_image = []


# for i in range(0,50,50):
#     track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
#     for i, t in enumerate(track_results['tracks']['items']):
#         artist_name.append(t['artists'][0]['name'])
#         track_name.append(t['name'])
#         track_id.append(t['id'])
#         popularity.append(t['popularity'])
#         artist_href.append(t['artists'][0]['external_urls']['spotify'])
#         track_href.append(t['external_urls']['spotify'])
#         album_image.append(t['album']['images'][0]['url'])

# %%
# Now going thorought the 126 genres and request Spotify API to return 112,000 artist name, track name, track_href and genre name

artist_name = []
track_name = []
genre_name = []
track_id = []
artist_href = []
track_href = []
# album_image = []



for genre in results['genres']:
    # print(genre)
    for i in range(0,1000,50):
        q1 = 'genre:'+str(genre)
        genre_results = sp.search(q=q1, type='track', limit=50,offset=i)
        for i, t in enumerate(genre_results['tracks']['items']):
            artist_name.append(t['artists'][0]['name'])
            track_name.append(t['name'])
            track_id.append(t['id'])
            artist_href.append(t['artists'][0]['external_urls']['spotify'])
            track_href.append(t['external_urls']['spotify'])
#             album_image.append(t['album']['images'][0]['url'])
            genre_name.append([genre])
    
spotify_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'artist_href' : artist_href, 'track_href' : track_href, 'genre_name' : genre_name})
print(spotify_dataframe.shape)
# Out:
# (112000, 6)

# %%
# Data Cleanup

# spotify_dataframe['genre_name'] = spotify_dataframe['genre_name'].str[0]
# spotify_dataframe

# %%
# Use Spotipy to then use Spotify API to return audio features for 112,000 tracks from sound_dataframe in batches of 100

rows = []
batchsize = 100
None_counter = 0

for i in range(0,len(spotify_dataframe['track_id']),batchsize):
    batch = spotify_dataframe['track_id'][i:i+batchsize]
    feature_results = sp.audio_features(batch)
    for i, t in enumerate(feature_results):
        if t == None:
            None_counter = None_counter + 1
        else:
            rows.append(t)

# %%
# Data Exploaration

# len(feature_results)
# feature_results

# %%
# Data Exploration

df_audio_features = pd.DataFrame.from_dict(rows,orient='columns')
print("Shape of the dataset:", df_audio_features.shape)
df_audio_features.head()
# Out:
# Shape of the dataset: (112000, 18)
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.686   0.457   11    -8.322     1       0.0468        0.5950
# 1         0.618   0.443    2    -9.681     1       0.0526        0.4690
# 2         0.672   0.623    9    -5.699     1       0.0297        0.2410
# 3         0.583   0.786    2    -3.142     0       0.0301        0.0208
# 4         0.697   0.474    9    -6.663     1       0.0351        0.6030
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0               0.0    0.1050    0.718  150.953  audio_features
# 1               0.0    0.0829    0.167  119.949  audio_features
# 2               0.0    0.0848    0.617   92.018  audio_features
# 3               0.0    0.1880    0.573  123.052  audio_features
# 4               0.0    0.1100    0.249  127.904  audio_features
#
#                        id                                   uri  \
# 0  1EzrEOXmMH3G43AXT1y7pA  spotify:track:1EzrEOXmMH3G43AXT1y7pA
# 1  5vjLSffimiIP26QG5WcN2K  spotify:track:5vjLSffimiIP26QG5WcN2K
# 2  38YgZVHPWOWsKrsCXz6JyP  spotify:track:38YgZVHPWOWsKrsCXz6JyP
# 3  4E6cwWJWZw2zWf7VFbH7wf  spotify:track:4E6cwWJWZw2zWf7VFbH7wf
# 4  0rFOs9paloAvEtzwDX1Kmc  spotify:track:0rFOs9paloAvEtzwDX1Kmc
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1EzrEOXmMH3G...
# 1  https://api.spotify.com/v1/tracks/5vjLSffimiIP...
# 2  https://api.spotify.com/v1/tracks/38YgZVHPWOWs...
# 3  https://api.spotify.com/v1/tracks/4E6cwWJWZw2z...
# 4  https://api.spotify.com/v1/tracks/0rFOs9paloAv...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1Ezr...       242187
# 1  https://api.spotify.com/v1/audio-analysis/5vjL...       198853
# 2  https://api.spotify.com/v1/audio-analysis/38Yg...       215173
# 3  https://api.spotify.com/v1/audio-analysis/4E6c...       258827
# 4  https://api.spotify.com/v1/audio-analysis/0rFO...       196280
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
# Data Cleanup

columns_to_drop = ['analysis_url','type','uri', 'track_href']
df_audio_features.drop(columns_to_drop, axis=1,inplace=True)
df_audio_features.rename(columns={'id': 'track_id'}, inplace=True)
df_audio_features.shape
# Out:
# (112000, 14)

# %%
# Data Cleanup
# Merge the two dataframes by spotify's unique track-id

audio_df = pd.merge(spotify_dataframe,df_audio_features,on='track_id',how='inner')
print("Shape of the dataset:", df_audio_features.shape)
audio_df.head()
# Out:
# Shape of the dataset: (112000, 14)
#   artist_name track_name                track_id  \
# 0  Jason Mraz  I'm Yours  1EzrEOXmMH3G43AXT1y7pA
# 1  Jason Mraz  I'm Yours  1EzrEOXmMH3G43AXT1y7pA
# 2  Jason Mraz  I'm Yours  1EzrEOXmMH3G43AXT1y7pA
# 3  Jason Mraz  I'm Yours  1EzrEOXmMH3G43AXT1y7pA
# 4  Jason Mraz  I'm Yours  1EzrEOXmMH3G43AXT1y7pA
#
#                                          artist_href  \
# 0  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 1  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 2  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 3  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 4  https://open.spotify.com/artist/4phGZZrJZRo4El...
#
#                                           track_href genre_name  danceability  \
# 0  https://open.spotify.com/track/1EzrEOXmMH3G43A...   acoustic         0.686
# 1  https://open.spotify.com/track/1EzrEOXmMH3G43A...   acoustic         0.686
# 2  https://open.spotify.com/track/1EzrEOXmMH3G43A...   acoustic         0.686
# 3  https://open.spotify.com/track/1EzrEOXmMH3G43A...        pop         0.686
# 4  https://open.spotify.com/track/1EzrEOXmMH3G43A...        pop         0.686
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.457   11    -8.322     1       0.0468         0.595               0.0
# 1   0.457   11    -8.322     1       0.0468         0.595               0.0
# 2   0.457   11    -8.322     1       0.0468         0.595               0.0
# 3   0.457   11    -8.322     1       0.0468         0.595               0.0
# 4   0.457   11    -8.322     1       0.0468         0.595               0.0
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0     0.105    0.718  150.953       242187               4
# 1     0.105    0.718  150.953       242187               4
# 2     0.105    0.718  150.953       242187               4
# 3     0.105    0.718  150.953       242187               4
# 4     0.105    0.718  150.953       242187               4

# %%
# Data Cleanup

audio_df['track_name'] = audio_df['track_name'].apply(lambda row: row.lower())
audio_df['artist_name'] = audio_df['artist_name'].apply(lambda row: row.lower())

# %%
# Data Exploration

audio_df.head()
# Out:
#   artist_name track_name                track_id  \
# 0  jason mraz  i'm yours  1EzrEOXmMH3G43AXT1y7pA
# 1  jason mraz  i'm yours  1EzrEOXmMH3G43AXT1y7pA
# 2  jason mraz  i'm yours  1EzrEOXmMH3G43AXT1y7pA
# 3  jason mraz  i'm yours  1EzrEOXmMH3G43AXT1y7pA
# 4  jason mraz  i'm yours  1EzrEOXmMH3G43AXT1y7pA
#
#                                          artist_href  \
# 0  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 1  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 2  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 3  https://open.spotify.com/artist/4phGZZrJZRo4El...
# 4  https://open.spotify.com/artist/4phGZZrJZRo4El...
#
#                                           track_href genre_name  danceability  \
# 0  https://open.spotify.com/track/1EzrEOXmMH3G43A...   acoustic         0.686
# 1  https://open.spotify.com/track/1EzrEOXmMH3G43A...   acoustic         0.686
# 2  https://open.spotify.com/track/1EzrEOXmMH3G43A...   acoustic         0.686
# 3  https://open.spotify.com/track/1EzrEOXmMH3G43A...        pop         0.686
# 4  https://open.spotify.com/track/1EzrEOXmMH3G43A...        pop         0.686
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.457   11    -8.322     1       0.0468         0.595               0.0
# 1   0.457   11    -8.322     1       0.0468         0.595               0.0
# 2   0.457   11    -8.322     1       0.0468         0.595               0.0
# 3   0.457   11    -8.322     1       0.0468         0.595               0.0
# 4   0.457   11    -8.322     1       0.0468         0.595               0.0
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0     0.105    0.718  150.953       242187               4
# 1     0.105    0.718  150.953       242187               4
# 2     0.105    0.718  150.953       242187               4
# 3     0.105    0.718  150.953       242187               4
# 4     0.105    0.718  150.953       242187               4

# %%
# Data Cleanup

# duplicated values by 
# audio_df = audio_df[audio_df.duplicated(subset=['track_href'],keep=False)]
# audio_df = audio_df[audio_df.duplicated(subset=['artist_name','track_name'],keep=False)]

# %%
# convert to csv

audio_df.to_csv ('audio_df.csv', index = False, header=True)
