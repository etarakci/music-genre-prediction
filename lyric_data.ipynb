# %%
import pandas as pd
import numpy as np
import requests

# %%
import sqlite3
# SQLITE DATABASE MUSIXMATCH
conn = sqlite3.connect("../final-data/mxm_dataset.db")
c = conn.cursor()

# %%
lyrics = c.execute('SELECT * FROM lyrics')
i = 0  
for row in lyrics:
    if i >= 20:
        break
    print(row)
    i+= 1
# Out:
# ('TRAAAAV128F421A322', 4623710, 'i', 6, 0)
# ('TRAAAAV128F421A322', 4623710, 'the', 4, 0)
# ('TRAAAAV128F421A322', 4623710, 'you', 2, 0)
# ('TRAAAAV128F421A322', 4623710, 'to', 2, 0)
# ('TRAAAAV128F421A322', 4623710, 'and', 5, 0)
# ('TRAAAAV128F421A322', 4623710, 'a', 3, 0)
# ('TRAAAAV128F421A322', 4623710, 'me', 1, 0)
# ('TRAAAAV128F421A322', 4623710, 'it', 1, 0)
# ('TRAAAAV128F421A322', 4623710, 'my', 1, 0)
# ('TRAAAAV128F421A322', 4623710, 'is', 2, 0)
# ('TRAAAAV128F421A322', 4623710, 'of', 3, 0)
# ('TRAAAAV128F421A322', 4623710, 'your', 1, 0)
# ('TRAAAAV128F421A322', 4623710, 'that', 1, 0)
# ('TRAAAAV128F421A322', 4623710, 'are', 2, 0)
# ('TRAAAAV128F421A322', 4623710, 'we', 2, 0)
# ('TRAAAAV128F421A322', 4623710, 'am', 2, 0)
# ('TRAAAAV128F421A322', 4623710, 'will', 2, 0)
# ('TRAAAAV128F421A322', 4623710, 'for', 4, 0)
# ('TRAAAAV128F421A322', 4623710, 'be', 1, 0)
# ('TRAAAAV128F421A322', 4623710, 'have', 2, 0)

# %%
words = c.execute('SELECT * FROM words')
i = 0
for row in words:
    if i >= 20:
        break
    print(row)
    i+= 1
# Out:
# ('i',)
# ('the',)
# ('you',)
# ('to',)
# ('and',)
# ('a',)
# ('me',)
# ('it',)
# ('not',)
# ('in',)
# ('my',)
# ('is',)
# ('of',)
# ('your',)
# ('that',)
# ('do',)
# ('on',)
# ('are',)
# ('we',)
# ('am',)

# %%
# BUNDLE ARCHIVE
artists_data = pd.read_csv("../final-data/bundle_archive/artists-data.csv")
lyrics_data = pd.read_csv("../final-data/bundle_archive/lyrics-data.csv")
artists_data.head()
# Out:
#               Artist  Songs  Popularity                 Link Genre  \
# 0      10000 Maniacs    110         0.3      /10000-maniacs/  Rock
# 1          12 Stones     75         0.3          /12-stones/  Rock
# 2                311    196         0.5                /311/  Rock
# 3      4 Non Blondes     15         7.5      /4-non-blondes/  Rock
# 4  A Cruz Está Vazia     13         0.0  /a-cruz-esta-vazia/  Rock
#
#                                               Genres
# 0  Rock; Pop; Electronica; Dance; J-Pop/J-Rock; G...
# 1  Rock; Gospel/Religioso; Hard Rock; Grunge; Roc...
# 2  Rock; Surf Music; Reggae; Ska; Pop/Rock; Rock ...
# 3  Rock; Pop/Rock; Rock Alternativo; Grunge; Blue...
# 4                                               Rock

# %%
artists_data['Artist'] = artists_data['Artist'].apply(lambda row: row.lower())
artists_data['Genre'] = artists_data['Genre'].apply(lambda row: row.lower())
artists_data['Genres'] = artists_data['Genres'].apply(lambda row: str(row).lower())
# artists_data.sort_values(by="Genre",ascending=True)
artists_data.sort_values(by="Artist",ascending=True,inplace=True)

artists_data.head()
# Out:
#               Artist  Songs  Popularity                 Link Genre  \
# 0      10000 maniacs    110         0.3      /10000-maniacs/  rock
# 1          12 stones     75         0.3          /12-stones/  rock
# 2                311    196         0.5                /311/  rock
# 3      4 non blondes     15         7.5      /4-non-blondes/  rock
# 4  a cruz está vazia     13         0.0  /a-cruz-esta-vazia/  rock
#
#                                               Genres
# 0  rock; pop; electronica; dance; j-pop/j-rock; g...
# 1  rock; gospel/religioso; hard rock; grunge; roc...
# 2  rock; surf music; reggae; ska; pop/rock; rock ...
# 3  rock; pop/rock; rock alternativo; grunge; blue...
# 4                                               rock

# %%
artists_data.sort_values(by="Link",ascending=True).head()
# Out:
#              Artist  Songs  Popularity             Link    Genre  \
# 2225     021 função      5         0.0     /021-funcao/  hip hop
# 1947  10000 maniacs    110         0.3  /10000-maniacs/      pop
# 0     10000 maniacs    110         0.3  /10000-maniacs/     rock
# 1         12 stones     75         0.3      /12-stones/     rock
# 2401         14 bis    120         1.8         /14-bis/      pop
#
#                                                  Genres
# 2225                             trip-hop; hip hop; rap
# 1947  rock; pop; electronica; dance; j-pop/j-rock; g...
# 0     rock; pop; electronica; dance; j-pop/j-rock; g...
# 1     rock; gospel/religioso; hard rock; grunge; roc...
# 2401  mpb; pop; folk; rock; romântico; soft rock; cl...

# %%
lyrics_data.head()
# Out:
#              ALink                    SName  \
# 0  /10000-maniacs/           More Than This
# 1  /10000-maniacs/        Because The Night
# 2  /10000-maniacs/           These Are Days
# 3  /10000-maniacs/          A Campfire Song
# 4  /10000-maniacs/  Everyday Is Like Sunday
#
#                                          SLink  \
# 0           /10000-maniacs/more-than-this.html
# 1        /10000-maniacs/because-the-night.html
# 2           /10000-maniacs/these-are-days.html
# 3          /10000-maniacs/a-campfire-song.html
# 4  /10000-maniacs/everyday-is-like-sunday.html
#
#                                                Lyric    Idiom
# 0  I could feel at the time. There was no way of ...  ENGLISH
# 1  Take me now, baby, here as I am. Hold me close...  ENGLISH
# 2  These are. These are days you'll remember. Nev...  ENGLISH
# 3  A lie to say, "O my mountain has coal veins an...  ENGLISH
# 4  Trudging slowly over wet sand. Back to the ben...  ENGLISH

# %%
lyrics_data['SName'] = lyrics_data['SName'].apply(lambda row: row.lower())
lyrics_data['Lyric'] = lyrics_data['Lyric'].apply(lambda row: str(row).lower())
lyrics_data['Idiom'] = lyrics_data['Idiom'].apply(lambda row: str(row).lower())
lyrics_data = lyrics_data[lyrics_data.Idiom == "english"]
lyrics_data.head()
# Out:
# /Users/erendiztarakci/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/erendiztarakci/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/erendiztarakci/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              ALink                    SName  \
# 0  /10000-maniacs/           more than this
# 1  /10000-maniacs/        because the night
# 2  /10000-maniacs/           these are days
# 3  /10000-maniacs/          a campfire song
# 4  /10000-maniacs/  everyday is like sunday
#
#                                          SLink  \
# 0           /10000-maniacs/more-than-this.html
# 1        /10000-maniacs/because-the-night.html
# 2           /10000-maniacs/these-are-days.html
# 3          /10000-maniacs/a-campfire-song.html
# 4  /10000-maniacs/everyday-is-like-sunday.html
#
#                                                Lyric    Idiom
# 0  i could feel at the time. there was no way of ...  english
# 1  take me now, baby, here as i am. hold me close...  english
# 2  these are. these are days you'll remember. nev...  english
# 3  a lie to say, "o my mountain has coal veins an...  english
# 4  trudging slowly over wet sand. back to the ben...  english

# %%
# add artists to lyrics df
lyrics_artist_data = pd.merge(lyrics_data, artists_data, how="left",left_on="ALink",right_on="Link")

# for some reason is creating duplicate rows with different Genre ?????
lyrics_artist_data.head(20)
# Out:
#                    ALink                                SName  \
# 0        /10000-maniacs/                       more than this
# 1        /10000-maniacs/                       more than this
# 2        /10000-maniacs/                    because the night
# 3        /10000-maniacs/                    because the night
# 4        /10000-maniacs/                       these are days
# ...                  ...                                  ...
# 129391           /sambo/                              valerie
# 129392           /sambo/                           wake me up
# 129393           /sambo/                           wake me up
# 129394       /seu-jorge/                                don't
# 129395  /zeca-pagodinho/  deixa a vida me levar (translation)
#
#                                                     SLink  \
# 0                      /10000-maniacs/more-than-this.html
# 1                      /10000-maniacs/more-than-this.html
# 2                   /10000-maniacs/because-the-night.html
# 3                   /10000-maniacs/because-the-night.html
# 4                      /10000-maniacs/these-are-days.html
# ...                                                   ...
# 129391                                /sambo/valerie.html
# 129392                             /sambo/wake-me-up.html
# 129393                             /sambo/wake-me-up.html
# 129394                               /seu-jorge/dont.html
# 129395  /zeca-pagodinho/deixa-a-vida-me-levar-translat...
#
#                                                     Lyric    Idiom  \
# 0       i could feel at the time. there was no way of ...  english
# 1       i could feel at the time. there was no way of ...  english
# 2       take me now, baby, here as i am. hold me close...  english
# 3       take me now, baby, here as i am. hold me close...  english
# 4       these are. these are days you'll remember. nev...  english
# ...                                                   ...      ...
# 129391  well sometimes i go out by myself. and i look ...  english
# 129392  feeling my way through the darkness. guided by...  english
# 129393  feeling my way through the darkness. guided by...  english
# 129394  don't, don't, that's what you say. each time t...  english
# 129395  i've been. for almost everything in life. in t...  english
#
#                 Artist  Songs  Popularity              Link  Genre  \
# 0        10000 maniacs  110.0         0.3   /10000-maniacs/   rock
# 1        10000 maniacs  110.0         0.3   /10000-maniacs/    pop
# 2        10000 maniacs  110.0         0.3   /10000-maniacs/   rock
# 3        10000 maniacs  110.0         0.3   /10000-maniacs/    pop
# 4        10000 maniacs  110.0         0.3   /10000-maniacs/   rock
# ...                ...    ...         ...               ...    ...
# 129391           sambô   71.0         0.8           /sambo/   rock
# 129392           sambô   71.0         0.8           /sambo/  samba
# 129393           sambô   71.0         0.8           /sambo/   rock
# 129394       seu jorge  106.0         4.2       /seu-jorge/  samba
# 129395  zeca pagodinho  309.0        13.2  /zeca-pagodinho/  samba
#
#                                                    Genres
# 0       rock; pop; electronica; dance; j-pop/j-rock; g...
# 1       rock; pop; electronica; dance; j-pop/j-rock; g...
# 2       rock; pop; electronica; dance; j-pop/j-rock; g...
# 3       rock; pop; electronica; dance; j-pop/j-rock; g...
# 4       rock; pop; electronica; dance; j-pop/j-rock; g...
# ...                                                   ...
# 129391  samba; pagode; rock; pop/rock; soul music; cla...
# 129392  samba; pagode; rock; pop/rock; soul music; cla...
# 129393  samba; pagode; rock; pop/rock; soul music; cla...
# 129394  mpb; samba; black music; romântico; pop; soul ...
# 129395  samba; pagode; bossa nova; mpb; jovem guarda; ...
#
# [129396 rows x 11 columns]

# %%
# lyrics_artist_data.head(20)
artists_data[artists_data.Link == "/10000-maniacs/"]
# Out:
#              Artist  Songs  Popularity             Link Genre  \
# 0     10000 maniacs    110         0.3  /10000-maniacs/  rock
# 1947  10000 maniacs    110         0.3  /10000-maniacs/   pop
#
#                                                  Genres
# 0     rock; pop; electronica; dance; j-pop/j-rock; g...
# 1947  rock; pop; electronica; dance; j-pop/j-rock; g...

# %%
lyrics_artist_data.drop("Link",1,inplace=True)
lyrics_artist_data.rename(columns={"Songs":"ASongs","Popularity":"APopularity","Genre":"AGenre","Genres":"AGenres"}, inplace=True)
lyrics_artist_data.head()
# Out:
#              ALink              SName                                  SLink  \
# 0  /10000-maniacs/     more than this     /10000-maniacs/more-than-this.html
# 1  /10000-maniacs/     more than this     /10000-maniacs/more-than-this.html
# 2  /10000-maniacs/  because the night  /10000-maniacs/because-the-night.html
# 3  /10000-maniacs/  because the night  /10000-maniacs/because-the-night.html
# 4  /10000-maniacs/     these are days     /10000-maniacs/these-are-days.html
#
#                                                Lyric    Idiom         Artist  \
# 0  i could feel at the time. there was no way of ...  english  10000 maniacs
# 1  i could feel at the time. there was no way of ...  english  10000 maniacs
# 2  take me now, baby, here as i am. hold me close...  english  10000 maniacs
# 3  take me now, baby, here as i am. hold me close...  english  10000 maniacs
# 4  these are. these are days you'll remember. nev...  english  10000 maniacs
#
#    ASongs  APopularity AGenre  \
# 0   110.0          0.3   rock
# 1   110.0          0.3    pop
# 2   110.0          0.3   rock
# 3   110.0          0.3    pop
# 4   110.0          0.3   rock
#
#                                              AGenres
# 0  rock; pop; electronica; dance; j-pop/j-rock; g...
# 1  rock; pop; electronica; dance; j-pop/j-rock; g...
# 2  rock; pop; electronica; dance; j-pop/j-rock; g...
# 3  rock; pop; electronica; dance; j-pop/j-rock; g...
# 4  rock; pop; electronica; dance; j-pop/j-rock; g...

# %%
# AZ LYRICS
import glob
az_lyrics = []
path = "../final-data/azlyrics-scraper/*.csv"
for fname in glob.glob(path):
#     az_lyrics.append(pd.read_csv(fname, sep='delimiter')) #876 rows
#     az_lyrics.append(pd.read_csv(fname, error_bad_lines=False)) #760 rows
    n = 5
    az_lyrics.append(pd.read_csv(fname, usecols=range(n),lineterminator='\n',)) #868 rows
az_lyrics[0]
# Out:
#     ARTIST_NAME                                 ARTIST_URL  \
# 0     03 greedo  https://www.azlyrics.com/19/03greedo.html
# 1     03 greedo  https://www.azlyrics.com/19/03greedo.html
# 2     03 greedo  https://www.azlyrics.com/19/03greedo.html
# 3     03 greedo  https://www.azlyrics.com/19/03greedo.html
# 4     03 greedo  https://www.azlyrics.com/19/03greedo.html
# ..          ...                                        ...
# 863     42 dugg    https://www.azlyrics.com/19/42dugg.html
# 864     42 dugg    https://www.azlyrics.com/19/42dugg.html
# 865     42 dugg    https://www.azlyrics.com/19/42dugg.html
# 866     42 dugg    https://www.azlyrics.com/19/42dugg.html
# 867     42 dugg    https://www.azlyrics.com/19/42dugg.html
#
#                    SONG_NAME  \
# 0                 sweet lady
# 1             mafia business
# 2                   paranoid
# 3                 never bend
# 4         prayer for my lost
# ..                       ...
# 863               naw 4 real
# 864                 not done
# 865                hoe nigga
# 866           marcelo burlon
# 867  whole city aka prada me
#
#                                               SONG_URL  \
# 0    https://www.azlyrics.com/lyrics/03greedo/sweet...
# 1    https://www.azlyrics.com/lyrics/03greedo/mafia...
# 2    https://www.azlyrics.com/lyrics/03greedo/paran...
# 3    https://www.azlyrics.com/lyrics/03greedo/never...
# 4    https://www.azlyrics.com/lyrics/03greedo/praye...
# ..                                                 ...
# 863  https://www.azlyrics.com/lyrics/42dugg/naw4rea...
# 864  https://www.azlyrics.com/lyrics/42dugg/notdone...
# 865  https://www.azlyrics.com/lyrics/42dugg/hoenigg...
# 866  https://www.azlyrics.com/lyrics/42dugg/marcelo...
# 867  https://www.azlyrics.com/lyrics/42dugg/wholeci...
#
#                                                 LYRICS
# 0    its only one, 03, i'm from grape street, where...
# 1    you gonna make me put you in a suit and tie, s...
# 2    we could kill it, yeah, we could, we could, we...
# 3    yeah, you lil bitch ass niggas steady speaking...
# 4    x loaded up bro, never see me in the church, p...
# ..                                                 ...
# 863  naw 4 real tho, that's a lie, nigga we really ...
# 864  if i died today, they'd bury me in san juan, w...
# 865  i ain't never been no hoe nigga, yeah, yeah, i...
# 866  like when i fuck her from the back, yeah, frea...
# 867  i got the whole city proud of me, i'm talkin' ...
#
# [868 rows x 5 columns]

# %%
# combine dataframes
az_data = pd.concat(az_lyrics)
az_data
# Out:
#         ARTIST_NAME                                   ARTIST_URL  \
# 0         03 greedo    https://www.azlyrics.com/19/03greedo.html
# 1         03 greedo    https://www.azlyrics.com/19/03greedo.html
# 2         03 greedo    https://www.azlyrics.com/19/03greedo.html
# 3         03 greedo    https://www.azlyrics.com/19/03greedo.html
# 4         03 greedo    https://www.azlyrics.com/19/03greedo.html
# ...             ...                                          ...
# 11970      jory boy      https://www.azlyrics.com/j/joryboy.html
# 11971      jory boy      https://www.azlyrics.com/j/joryboy.html
# 11972      jory boy      https://www.azlyrics.com/j/joryboy.html
# 11973      jory boy      https://www.azlyrics.com/j/joryboy.html
# 11974  josef salvat  https://www.azlyrics.com/j/josefsalvat.html
#
#                 SONG_NAME                                           SONG_URL  \
# 0              sweet lady  https://www.azlyrics.com/lyrics/03greedo/sweet...
# 1          mafia business  https://www.azlyrics.com/lyrics/03greedo/mafia...
# 2                paranoid  https://www.azlyrics.com/lyrics/03greedo/paran...
# 3              never bend  https://www.azlyrics.com/lyrics/03greedo/never...
# 4      prayer for my lost  https://www.azlyrics.com/lyrics/03greedo/praye...
# ...                   ...                                                ...
# 11970     por que cambiar  https://www.azlyrics.com/lyrics/joryboy/porque...
# 11971      imposible amor  https://www.azlyrics.com/lyrics/joryboy/imposi...
# 11972              bonita  https://www.azlyrics.com/lyrics/joryboy/bonita...
# 11973      no me condenes  https://www.azlyrics.com/lyrics/joryboy/nomeco...
# 11974              closer  https://www.azlyrics.com/lyrics/josefsalvat/cl...
#
#                                                   LYRICS
# 0      its only one, 03, i'm from grape street, where...
# 1      you gonna make me put you in a suit and tie, s...
# 2      we could kill it, yeah, we could, we could, we...
# 3      yeah, you lil bitch ass niggas steady speaking...
# 4      x loaded up bro, never see me in the church, p...
# ...                                                  ...
# 11970  , los evos jedis, no entiendo como, esto suced...
# 11971  yo se que lo que tuvimos anoche te gusto, echa...
# 11972  , dice, matando la liga baby, jory boy, baby d...
# 11973  , no se lo que te sucedio, quien te convirtio ...
# 11974  oh we're further than before, and it's harder ...
#
# [147872 rows x 5 columns]
